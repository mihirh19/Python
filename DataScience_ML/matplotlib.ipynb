# %% [markdown]
# # matplotlib

# %% [markdown]
# ## importing libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x = np.array([0, 1, 2, 3, 4, 5])
y = np.array([0, 10, 9, 2, 20, 40])

# %%
x, y
# Out:
# (array([0, 1, 2, 3, 4, 5]), array([ 0, 10,  9,  2, 20, 40]))

# %%
plt.plot(x, y)
plt.show()

# %% [markdown]
# ## MAking a plot without line

# %%
plt.plot(x, y, 'o')
# 'o' -> marks
plt.show()

# %%
plt.plot(x, y, '*')

# %%
 # - ->solid line
# : -> dotted line
# -- -> dashed line
# -. -> dashed/doted line

# %% [markdown]
# * Format String (fmt)

# %%
plt.plot(x, y, 'd:r')

# d -> dimand shape
# : -> doted line
# r -> red color line

# %%
plt.plot(y, marker='*', ms=10)

# %%
plt.plot(y, marker='*', ms=10, mec='red')
plt.show()

# %% [markdown]
# ## line style

# %%
plt.plot(y, linestyle='dashed')

# %%
plt.plot(y, ls=':', color='red', linewidth='5')

# %%
plt.plot(x)
plt.plot(y)
plt.show()

# %%
x = [3, 8, 1, 10]
y = [6, 2, 7, 11]

# %%
plt.plot(x)
plt.plot(y)
plt.show()

# %% [markdown]
# * Labels

# %%
plt.plot(x)
plt.plot(y)
plt.ylabel('weight')
plt.xlabel('height')
plt.show()

# %% [markdown]
# * Title

# %%
plt.plot(x)
plt.plot(y)
plt.ylabel('weight')
plt.xlabel('height')
modi = {'color': "red", 'size': 15, 'family': 'serif'}
plt.title("Height v/s weight graph", fontdict=modi, loc='left')
plt.show()

# %%
plt.plot(x)
plt.plot(y)
plt.grid(color='black', ls='--', linewidth=1)
plt.show()

# %% [markdown]
# * subplot

# %%
x = [1, 2, 3, 4, 5, 6]
y = [10, 20, 30, 40, 50, 60]

plt.subplot(2, 2, 1)
plt.plot(x, y)

x = [3, 8, 1, 10]
y = [6, 2, 7, 11]
plt.subplot(2, 2, 2)
plt.plot(x, y)

x = [1, 2, 3, 4, 5, 6]
y = [10, 20, 30, 40, 50, 60]

plt.subplot(2, 2, 3)
plt.plot(x, y)

x = [3, 8, 1, 10]
y = [6, 2, 7, 11]
plt.subplot(2, 2, 4)
plt.plot(x, y)
plt.suptitle("animals")
plt.show()

# %% [markdown]
# * Ticks and ticks label

# %%
x = [3, 8, 1, 10]
y = [6, 2, 7, 11]

fig = plt.figure()
ax = fig.add_axes([1, 1, 2, 2])
ax.plot(x, y)
ax.set_title("animal")
ax.set_xlabel('x axis')
ax.set_ylabel('y axis')

ax.set_xticklabels([100, 102, 103, 104, 106, 108])
ax.set_yticklabels(['one', 'two', 'three', 'four', 'five', 'six'])
# Out:
# C:\Users\Mihir\AppData\Local\Temp\ipykernel_21012\2698213393.py:11: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels([100, 102, 103, 104, 106, 108])
# C:\Users\Mihir\AppData\Local\Temp\ipykernel_21012\2698213393.py:12: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(['one', 'two', 'three', 'four', 'five', 'six'])
# [Text(0, 0.0, 'one'),
#  Text(0, 2.0, 'two'),
#  Text(0, 4.0, 'three'),
#  Text(0, 6.0, 'four'),
#  Text(0, 8.0, 'five'),
#  Text(0, 10.0, 'six'),
#  Text(0, 12.0, '')]

# %% [markdown]
# ## Scatter plot

# %%
x = [3, 8, 1, 10, 5, 7, 22, 55, 6, 3, 7, 11, 44, 8, 45, 67]
y = [6, 2, 7, 11, 68, 67, 23, 67, 34, 67, 1, 223, 45, 67, 48, 54]
plt.scatter(x, y)

# %%
x = [5, 7, 8, 7, 2, 17, 2, 9, 4, 11, 12, 9, 6]
y = [99, 86, 87, 88, 111, 86, 103, 87, 94, 78, 777, 85, 86]
plt.scatter(x, y)

# %%
df = pd.read_csv('AAL_data.csv')

# %%
df.head()
# Out:
#          date   open   high    low  close    volume Name
# 0  2013-02-08  15.07  15.12  14.63  14.75   8407500  AAL
# 1  2013-02-11  14.89  15.01  14.26  14.46   8882000  AAL
# 2  2013-02-12  14.45  14.51  14.10  14.27   8126000  AAL
# 3  2013-02-13  14.30  14.94  14.25  14.66  10259500  AAL
# 4  2013-02-14  14.94  14.96  13.16  13.99  31879900  AAL

# %% [markdown]
# plt.scatter(df.high, df.low)

# %%
plt.scatter(df.open, df.close)

# %% [markdown]
# ## Bar plot

# %%
x = ['One', 'two', 'three', 'four']
y = [6, 9, 1, 20]

# %%
plt.bar(x, y)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.barh(x, y)
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# ## histogram

# %%
x = np.random.normal(200, 10, 300)

# %%
x
# Out:
# array([193.37330684, 202.05575987, 195.03257849, 202.54019006,
#        196.59363429, 180.88191086, 206.12756995, 199.22299813,
#        203.4552133 , 210.00556165, 204.05755681, 217.99687471,
#        207.33023765, 191.51204982, 194.29173646, 203.06202508,
#        206.9860528 , 193.65132023, 173.07040719, 191.51086358,
#        200.73384082, 203.65608778, 197.29886495, 217.47105567,
#        207.01046397, 188.65213113, 193.84352917, 207.84467959,
#        217.48373134, 191.18099937, 184.15206879, 194.24656058,
#        217.23231767, 199.15371291, 204.78036957, 197.72998321,
#        190.3314903 , 198.62054431, 193.0513225 , 198.81085003,
#        196.30089468, 192.74653677, 207.75794263, 197.24102539,
#        190.57164061, 201.86212733, 174.75350929, 200.88435763,
#        190.575778  , 211.2670703 , 202.31697015, 197.265311  ,
#        195.65630717, 172.35134886, 208.86122443, 204.05652263,
#        189.86050157, 209.7565912 , 199.64313234, 213.53822028,
# ...

# %%
plt.hist(x)
# Out:
# (array([ 7.,  6., 19., 35., 55., 61., 53., 37., 17., 10.]),
#  array([172.35134886, 177.39630414, 182.44125942, 187.4862147 ,
#         192.53116998, 197.57612526, 202.62108054, 207.66603582,
#         212.7109911 , 217.75594638, 222.80090166]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## pie chart

# %%
x = [25, 25, 35, 15]
plt.pie(x, labels=['chocolate', 'vanilla', 'strawberry', 'blackcurrant'])
# Out:
# ([<matplotlib.patches.Wedge at 0x29bd6db3150>,
# ...
#  [Text(0.7778174593052024, 0.7778174593052024, 'chocolate'),
#   Text(-0.7778174593052023, 0.7778174593052024, 'vanilla'),
#   Text(-0.49938956806635254, -0.9801071672559598, 'strawberry'),
#   Text(0.9801071672559598, -0.4993895680663526, 'blackcurrant')])

# %%
plt.pie(x, labels=['chocolate', 'vanilla', 'strawberry', 'blackcurrant'], explode=[0.2, 0, 0, 0])
# Out:
# ([<matplotlib.patches.Wedge at 0x29bd6e34610>,
# ...
#  [Text(0.919238815542512, 0.919238815542512, 'chocolate'),
#   Text(-0.7778174593052023, 0.7778174593052024, 'vanilla'),
#   Text(-0.49938956806635254, -0.9801071672559598, 'strawberry'),
#   Text(0.9801071672559598, -0.4993895680663526, 'blackcurrant')])

# %%
plt.pie(x, labels=['chocolate', 'vanilla', 'strawberry', 'blackcurrant'], explode=[0.2, 0, 0, 0], shadow=True,
        colors=['red', 'green', 'yellow', 'blue'])
# Out:
# ([<matplotlib.patches.Wedge at 0x29bd6e7ca90>,
# ...
#  [Text(0.919238815542512, 0.919238815542512, 'chocolate'),
#   Text(-0.7778174593052023, 0.7778174593052024, 'vanilla'),
#   Text(-0.49938956806635254, -0.9801071672559598, 'strawberry'),
#   Text(0.9801071672559598, -0.4993895680663526, 'blackcurrant')])

# %%
plt.pie(x, labels=['chocolate', 'vanilla', 'strawberry', 'blackcurrant'], explode=[0.2, 0, 0, 0], shadow=True,
        colors=['red', 'green', 'yellow', 'blue'])
plt.legend(title='Ice cream flavors')
